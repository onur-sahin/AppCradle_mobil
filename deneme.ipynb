# %%
def deneme(a, *args):
    print(a)
    print(args[2])

# %%
import os

path = os.getcwd()+"\\deneme.ipynb"
print(os.path.dirname(path))
# Out:
# c:\Users\adam\GitHub\AppCradle_mobil

# %%
import threading

def deneme():
    print("################")

threading.Timer(interval=10, function=deneme).start()

print("+++++++++++++++")
# Out:
# +++++++++++++++
# ################

# %%
import io
k = str.encode("eauyşamlyu")
k
# Out:
# b'eauy\xc5\x9famlyu'
